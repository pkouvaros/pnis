# %%
from GuardSwarmDilemma import Simulation
sim = Simulation(number_of_agents=3)
sim.train(n_episodes=10)
# Out:
# 2024-01-14 13:29:30.718862: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Running Episodes:   0%|          | 0/10 [00:00<?, ?it/s]2024-01-14 13:29:30.929296: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2024-01-14 13:29:30.948175: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2600000000 Hz
# Running Episodes:  70%|███████   | 7/10 [00:19<00:03,  1.13s/it]

# %%
import pandas as pd
df = pd.read_csv("traininghistory/history.csv", index_col="Episode")
# plot loss
df.plot(title='Training', xlabel='Training Iteration')
# Out:
# <Axes: title={'center': 'Training'}, xlabel='Training Iteration'>

# %%
df["Average Reward"].rolling(64).mean().plot(
    title='Training', xlabel='Training Iteration', legend=True)
# Out:
# <Axes: title={'center': 'Training'}, xlabel='Training Iteration'>
